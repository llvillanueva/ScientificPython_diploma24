# %%
import pandas as pd
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from scipy.integrate import quad
from scipy.interpolate import interp1d, lagrange, splrep, splev

# %% [markdown]
# #### **Exercise 1:**
#
# Repeat the curve fitting example with the following modifications:
#
#  - choose some other function
#  - first write the data to a file, then read it (with numpy, for example)
#  - produce the picture that has axes, name and legend

# %%
from scipy import optimize

np.random.seed(0)

# Let's generate fake data that we can "fit" then 
def f(x, a, phi):
    return np.cos(a * x + phi) + np.sin( phi)

#random makes it look like experimental data
x = np.linspace(0, 4, 50)
y = f(x, 1.3, 0.9) + .1*np.random.normal(size=50)
data =np.column_stack((x,y))

# %%
np.savetxt('data/E1data.txt',  data, fmt ='%f')

# %%
x_read, y_read = np.loadtxt('data/E1data.txt', unpack=True)

# %%
# Now fit the model: the parameters omega and phi can be found in the
# `params` vector
params, params_cov = optimize.curve_fit(f, x, y)

print(params)

# plot the data and the fitted curve
plt.plot(x_read, y_read, 'bx', label='data')
plt.plot(x_read,f(x_read,1.3,0.9),'g-', label = "Curve fit 1")
plt.plot(x_read, f(x_read, *params), 'r-', label = "Curve fit 2")
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
# Out:
# [1.28727212 0.90508365]

# %% [markdown]
# #### **Exercise 2:**
#
# Integrate the function `x**2 + 10*np.sin(x)` on the interval `[-10,10]`.
# Find a way to make a plot like in textbooks where you color the area under the curve that you integrate.
# Now integrate the same function symbolically using `sympy`, then put borders into it and compare the results.

# %%
def func(x):
    return x**2 + 10*np.sin(x)

x_values = np.linspace(-10, 10, 1000)
y_values = func(x_values)

result = quad(func, -10, 10)

# Symbolic integration using sympy
x = sp.symbols('x')
f_sym = x**2 + 10*sp.sin(x)
area_sym = sp.integrate(f_sym, (x, -10, 10))

plt.plot(x_values, y_values, label=f'f(x) = {f_sym}', color='black')
plt.fill_between(x_values, y_values, color='cyan', alpha=0.3, label='Integrated area')
plt.title('Integration')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()

# %%
print("Sympy Result:", area_sym.evalf())
print("Scipy Result:", result)
# Out:
# Sympy Result: 666.666666666667
# Scipy Result: (666.6666666666667, 7.655722985888797e-12)

# %% [markdown]
# #### **Exercise 3**
#
# With the help of documentation find 3 different ways to interpolate data produced from the function
# `np.cos(-x**2/9.0)`.
# Create a class called "My_Interpolation" with these 3 interpolation methods.

# %%
class My_Interpolation:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def linear_interpolation(self, new_x):
        f_linear = interp1d(self.x, self.y, kind='linear')
        return f_linear(new_x)

    def polynomial_interpolation(self, new_x):
        f_poly = lagrange(self.x, self.y)
        return f_poly(new_x)

    def spline_interpolation(self, new_x):
        tck = splrep(self.x, self.y, s=0)
        return splev(new_x, tck)

# generating data
x = np.linspace(-5, 5, 20)
y = np.cos(-x**2/3.0) + np.tanh(x**2)

# Creating an instance of My_Interpolation
interpolator = My_Interpolation(x, y)

# Generating new x values for interpolation
new_x_values = np.linspace(-5, 5, 100)

# Interpolating using different methods
y_linear = interpolator.linear_interpolation(new_x_values)
y_poly = interpolator.polynomial_interpolation(new_x_values)
y_spline = interpolator.spline_interpolation(new_x_values)

plt.plot(x, y, 'o', label='Original Data')
plt.plot(new_x_values, y_linear, label='Linear Interpolation')
plt.plot(new_x_values, y_poly, label='Polynomial Interpolation')
plt.plot(new_x_values, y_spline, label='Spline Interpolation')
plt.legend()
plt.title('Interpolation of cos(-x**2/3.0) + tanh(x**2)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# #### **Exercise 4:**
# Give students in the `example.csv` file a bonus of 5 for all the courses. Find a way to replace all the values that are now greater than 30 by 30. Save the new data to a file. Make a plot with histograms for every course in the example file.

# %%
#Read the file, save it to df4, and show df4
df4 = pd.read_csv('data/example.csv', index_col=0)
df4
# Out:
#         course1  course2  course3  course4
# name
# Marie        24       18       30       20
# John         18       27       29       27
# Kati         21       24       28       27
# Olaf         30       30       29       30
# Mark         24       25       27       21
# Olga         23       26       30       30
# Jean         18       28       26       24
# Alex         19       20       27       27
# Pier         24       29       23       26
# Bennet       24       25       26       30
# Luis         20       20       18       18

# %%
#Add 5 bonus for all the courses and make 30 as a cap score, save it to df4_bonus, and show it
df4_bonus = df4.map(lambda x: x+5 if (x + 5) <= 30 else 30)
df4_bonus
# Out:
#         course1  course2  course3  course4
# name
# Marie        29       23       30       25
# John         23       30       30       30
# Kati         26       29       30       30
# Olaf         30       30       30       30
# Mark         29       30       30       26
# Olga         28       30       30       30
# Jean         23       30       30       29
# Alex         24       25       30       30
# Pier         29       30       28       30
# Bennet       29       30       30       30
# Luis         25       25       23       23

# %%
df4_bonus + 5
# Out:
#         course1  course2  course3  course4
# name
# Marie        34       28       35       30
# John         28       35       35       35
# Kati         31       34       35       35
# Olaf         35       35       35       35
# Mark         34       35       35       31
# Olga         33       35       35       35
# Jean         28       35       35       34
# Alex         29       30       35       35
# Pier         34       35       33       35
# Bennet       34       35       35       35
# Luis         30       30       28       28

# %%
df4_bonus2 = df4.map(lambda x: 30 if (x + 5) > 30 else x+5)
df4_bonus2
# Out:
#         course1  course2  course3  course4
# name
# Marie        29       23       30       25
# John         23       30       30       30
# Kati         26       29       30       30
# Olaf         30       30       30       30
# Mark         29       30       30       26
# Olga         28       30       30       30
# Jean         23       30       30       29
# Alex         24       25       30       30
# Pier         29       30       28       30
# Bennet       29       30       30       30
# Luis         25       25       23       23

# %%
#save the new dataframe to example_bonus.csv
df4_bonus.to_csv('data/example_bonus.csv', index=False)

# %%
#plot the new dataframe
df4.hist(figsize=(10, 8), bins=10, edgecolor='black', grid=False)
plt.suptitle('Histograms for Every Course')
plt.show()

# %% [markdown]
# #### **Exercise 5:**
#
#  - Read in the `cars.csv` file as a dataframe
#  - Remove the row with the index 3, which contains a quote in the Model column.
#  - Add a new column called Price with the following values: [8000, 6500, 7000, 6800, 7500, 7300, 7000, 9000, 6500, 7800]
#  - Find the average Length of all the vehicles.
#  - Find the median Price of all the vehicles.
#  - Create a new dataframe that only contains the rows where the Price is greater than 7000.
#  - Sort the dataframe in descending order by the Price column.

# %%
df = pd.read_csv('data/cars.csv', index_col=0)
df
# Out:
#            Make                        Model  Length
# Year
# 1997       Ford                         E350    2.34
# 2000    Mercury                       Cougar    2.38
# 1993  Chevrolet  Venture "Extended Edition"     3.20
# 1999       Jeep               Grand Cherokee    2.56
# 1998      Dodge                     Intrepid    3.01
# 1997       Ford                         E350    2.34
# 1999       Ford                         E350    2.34
# 1996       Ford                      Mustang    2.37
# 2000       Ford                      Mustang    2.34
# 1997       Ford                       Taurus    2.34

# %%
df = df.drop(['Model'], axis=1)
df
# Out:
#            Make  Length
# Year
# 1997       Ford    2.34
# 2000    Mercury    2.38
# 1993  Chevrolet    3.20
# 1999       Jeep    2.56
# 1998      Dodge    3.01
# 1997       Ford    2.34
# 1999       Ford    2.34
# 1996       Ford    2.37
# 2000       Ford    2.34
# 1997       Ford    2.34

# %%
df['Price'] = [8000, 6500, 7000, 6800, 7500, 7300, 7000, 9000, 6500, 7800]

# %%
df
# Out:
#            Make  Length  Price
# Year
# 1997       Ford    2.34   8000
# 2000    Mercury    2.38   6500
# 1993  Chevrolet    3.20   7000
# 1999       Jeep    2.56   6800
# 1998      Dodge    3.01   7500
# 1997       Ford    2.34   7300
# 1999       Ford    2.34   7000
# 1996       Ford    2.37   9000
# 2000       Ford    2.34   6500
# 1997       Ford    2.34   7800

# %%
average_length = df['Length'].mean()
median_price = df['Price'].median()

print('Average Length: ',average_length)
print('Median Price: ',median_price)
# Out:
# Average Length:  2.522
# Median Price:  7150.0

# %%
high_price_df = df[df['Price'] > 7000]
high_price_df
# Out:
#        Make  Length  Price
# Year
# 1997   Ford    2.34   8000
# 1998  Dodge    3.01   7500
# 1997   Ford    2.34   7300
# 1996   Ford    2.37   9000
# 1997   Ford    2.34   7800

# %%
sorted_high_price_df = high_price_df.sort_values(by='Price', ascending=False)
sorted_high_price_df

df.sort_values
# Out:
#        Make  Length  Price
# Year
# 1996   Ford    2.37   9000
# 1997   Ford    2.34   8000
# 1997   Ford    2.34   7800
# 1998  Dodge    3.01   7500
# 1997   Ford    2.34   7300

# %% [markdown]
# #### **Exercise 6:**
#  - create a random matrix with numpy
#  - save it to file
#  - read it back with numpy
#  - calculate some statistcs on it with numpy
#  - read the same file with pandas
#  - calculate the same statistics on it with pandas

# %%
N = 5
random_matrix = np.random.rand(N, N)
random_matrix
# Out:
# array([[0.15896958, 0.11037514, 0.65632959, 0.13818295, 0.19658236],
#        [0.36872517, 0.82099323, 0.09710128, 0.83794491, 0.09609841],
#        [0.97645947, 0.4686512 , 0.97676109, 0.60484552, 0.73926358],
#        [0.03918779, 0.28280696, 0.12019656, 0.2961402 , 0.11872772],
#        [0.31798318, 0.41426299, 0.0641475 , 0.69247212, 0.56660145]])

# %%
np.savetxt('data/random_matrix.txt',  random_matrix, fmt ='%f', delimiter=',')

# %%
load_matrix = np.loadtxt('data/random_matrix.txt', delimiter=',')

# %%
load_matrix
# Out:
# array([[0.15897 , 0.110375, 0.65633 , 0.138183, 0.196582],
#        [0.368725, 0.820993, 0.097101, 0.837945, 0.096098],
#        [0.976459, 0.468651, 0.976761, 0.604846, 0.739264],
#        [0.039188, 0.282807, 0.120197, 0.29614 , 0.118728],
#        [0.317983, 0.414263, 0.064147, 0.692472, 0.566601]])

# %%
np_mean = np.mean(load_matrix)
np_std = np.std(load_matrix)
np_sum = np.sum(load_matrix)
np_median = np.median(load_matrix)

# %%
print("NumPy Statistics:")
print(f"Mean: {np_mean}, Standard Deviation: {np_std}, Sum: {np_sum}, Median: {np_median} ")
# Out:
# NumPy Statistics:
# Mean: 0.40639235999999995, Standard Deviation: 0.2995041459169312, Sum: 10.159809, Median: 0.317983

# %%
loaded_matrix_pd = pd.read_csv('data/random_matrix.txt', header=None).values

# %%
pd_mean = loaded_matrix_pd.mean()
pd_std = loaded_matrix_pd.std()
pd_sum = loaded_matrix_pd.sum()
pd_median = loaded_matrix_pd.median()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 4
#       2 pd_std = loaded_matrix_pd.std()
#       3 pd_sum = loaded_matrix_pd.sum()
# ----> 4 pd_median = loaded_matrix_pd.median()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
print("\nPandas Statistics:")
print(f"Mean: {pd_mean}, Standard Deviation: {pd_std}, Sum: {pd_sum}, Median: {np_median} ")
# Out:
# Pandas Statistics:
# Mean: 0.40639236000000006, Standard Deviation: 0.29950414591693114, Sum: 10.159809000000001
